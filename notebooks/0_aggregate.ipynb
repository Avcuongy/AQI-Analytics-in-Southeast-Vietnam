# %% [markdown]
# # Lib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_1 = pd.read_csv(
    "B:\_projects\AQI-Analytics-in-Southeast-Vietnam\data\historical\air_quality\air_quality_year_2023.csv"
)
df_2 = pd.read_csv(
    "B:\_projects\AQI-Analytics-in-Southeast-Vietnam\data\historical\air_quality\air_quality_year_2024.csv"
)
df_3 = pd.read_csv(
    "B:\_projects\AQI-Analytics-in-Southeast-Vietnam\data\historical\air_quality\air_quality_year_2025.csv"
)
df_aqi = pd.concat([df_1, df_2, df_3], axis=0, ignore_index=True)
df_aqi.head()

# %%
df_1 = pd.read_csv(
    "B:\_projects\AQI-Analytics-in-Southeast-Vietnam\data\historical\weather\weather_year_2023.csv"
)
df_2 = pd.read_csv(
    "B:\_projects\AQI-Analytics-in-Southeast-Vietnam\data\historical\weather\weather_year_2024.csv"
)
df_3 = pd.read_csv(
    "B:\_projects\AQI-Analytics-in-Southeast-Vietnam\data\historical\weather\weather_year_2025.csv"
)
df_weather = pd.concat([df_1, df_2, df_3], axis=0, ignore_index=True)
df_weather.head()
