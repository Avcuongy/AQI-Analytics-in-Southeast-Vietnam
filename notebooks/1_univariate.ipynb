# %% [markdown]
# # Lib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %%
df = pd.read_csv("../data/clean/data.csv", parse_dates=["date"])
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (246640, 30)
#    location_id     location_name                date  pm10  pm2_5  \
# 0      1566083  Ho Chi Minh City 2022-08-05 07:00:00  31.7   21.9
# 1      1566083  Ho Chi Minh City 2022-08-05 08:00:00  29.2   20.1
# 2      1566083  Ho Chi Minh City 2022-08-05 09:00:00  26.4   18.2
# 3      1566083  Ho Chi Minh City 2022-08-05 10:00:00  24.5   16.8
# 4      1566083  Ho Chi Minh City 2022-08-05 11:00:00  23.8   16.2
#
#    carbon_monoxide  sulphur_dioxide  ozone  nitrogen_dioxide  \
# 0            498.0             8.70    9.0             28.05
# 1            487.0             9.25   14.0             28.10
# 2            470.0            10.10   21.0             28.15
# 3            432.0            10.90   34.0             26.35
# 4            381.0            11.10   47.0             22.00
#
#    aerosol_optical_depth  ...  rain  surface_pressure  cloud_cover  \
# 0                   0.12  ...   0.0        1007.80760        100.0
# 1                   0.12  ...   0.0        1008.31116        100.0
# 2                   0.13  ...   0.0        1008.51447        100.0
# 3                   0.13  ...   0.0        1008.11725        100.0
# 4                   0.14  ...   0.1        1007.71950        100.0
#
#    wind_speed_10m  wind_direction_10m  weather_code  sunshine_duration  \
# 0        2.305125           308.65982           3.0             3600.0
# 1        8.905908           284.03625           3.0             3600.0
# 2       10.440001           270.00000           3.0             3600.0
# 3       13.910169           280.43740           3.0             3600.0
# 4       16.854767           289.98320          51.0             3600.0
#
#    boundary_layer_height  dew_point_2m  is_day
# 0                  310.0         24.35     1.0
# 1                  520.0         24.45     1.0
# 2                  635.0         24.55     1.0
# 3                  780.0         24.60     1.0
# 4                  875.0         24.55     1.0
#
# [5 rows x 30 columns]

# %% [markdown]
# # Data Quality Check

# %% [markdown]
# ## Overview

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246640 entries, 0 to 246639
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   location_id              246640 non-null  int64
#  1   location_name            246640 non-null  object
#  2   date                     246640 non-null  datetime64[ns]
#  3   pm10                     246640 non-null  float64
#  4   pm2_5                    246640 non-null  float64
#  5   carbon_monoxide          246640 non-null  float64
#  6   sulphur_dioxide          246640 non-null  float64
#  7   ozone                    246640 non-null  float64
#  8   nitrogen_dioxide         246640 non-null  float64
#  9   aerosol_optical_depth    246640 non-null  float64
#  10  dust                     246640 non-null  float64
#  11  us_aqi_pm2_5             246640 non-null  float64
#  12  us_aqi_pm10              246640 non-null  float64
#  13  us_aqi_nitrogen_dioxide  246640 non-null  float64
#  14  us_aqi_carbon_monoxide   246640 non-null  float64
#  15  us_aqi_ozone             246640 non-null  float64
#  16  us_aqi_sulphur_dioxide   246640 non-null  float64
#  17  us_aqi                   246640 non-null  float64
#  18  temperature_2m           246640 non-null  float64
#  19  relative_humidity_2m     246640 non-null  float64
#  20  rain                     246640 non-null  float64
#  21  surface_pressure         246640 non-null  float64
#  22  cloud_cover              246640 non-null  float64
#  23  wind_speed_10m           246640 non-null  float64
#  24  wind_direction_10m       246640 non-null  float64
#  25  weather_code             246640 non-null  float64
#  26  sunshine_duration        246640 non-null  float64
#  27  boundary_layer_height    246640 non-null  float64
#  28  dew_point_2m             246640 non-null  float64
#  29  is_day                   246640 non-null  float64
# dtypes: datetime64[ns](1), float64(27), int64(1), object(1)
# memory usage: 56.5+ MB

# %%
n_locations = df["location_id"].nunique()
date_range_days = (df["date"].max() - df["date"].min()).days + 1
expected_rows = n_locations * date_range_days * 24

print(f"Locations       : {n_locations}")
print(
    f"Date range      : {df['date'].min()}  ->  {df['date'].max()}  ({date_range_days} days)"
)
print(f"Expected rows   : {expected_rows:,}")
print(f"Actual rows     : {len(df):,}")
print(
    f"Missing rows    : {expected_rows - len(df):,} rows ({(expected_rows - len(df)) / expected_rows * 100:.2f}%)"
)
# Out:
# Locations       : 10
# Date range      : 2022-08-05 07:00:00  ->  2026-06-28 23:00:00  (1424 days)
# Expected rows   : 341,760
# Actual rows     : 246,640
# Missing rows    : 95,120 rows (27.83%)

# %%
df[["location_id", "location_name"]].drop_duplicates().reset_index(drop=True)
# Out:
#    location_id     location_name
# 0      1566083  Ho Chi Minh City
# 1      1587923          Bien Hoa
# 2      9075789        Long Khánh
# 3      1565022       Thu Dau Mot
# 4     12382296          Thuận An
# 5      1583518             Dĩ An
# 6      8594709  Thanh Pho Ba Ria
# 7      1562414          Vũng Tàu
# 8      1566559          Tay Ninh
# 9      1582436         Dong Xoai

# %% [markdown]
# ## Dtype

# %%
print(df.dtypes)
# Out:
# location_id                         int64
# location_name                      object
# date                       datetime64[ns]
# pm10                              float64
# pm2_5                             float64
# carbon_monoxide                   float64
# sulphur_dioxide                   float64
# ozone                             float64
# nitrogen_dioxide                  float64
# aerosol_optical_depth             float64
# dust                              float64
# us_aqi_pm2_5                      float64
# us_aqi_pm10                       float64
# us_aqi_nitrogen_dioxide           float64
# us_aqi_carbon_monoxide            float64
# us_aqi_ozone                      float64
# us_aqi_sulphur_dioxide            float64
# us_aqi                            float64
# temperature_2m                    float64
# relative_humidity_2m              float64
# rain                              float64
# surface_pressure                  float64
# cloud_cover                       float64
# wind_speed_10m                    float64
# wind_direction_10m                float64
# weather_code                      float64
# sunshine_duration                 float64
# boundary_layer_height             float64
# dew_point_2m                      float64
# is_day                            float64
# dtype: object

# %% [markdown]
# ## Missing value

# %%
missing_count = df.isnull().sum()
missing_pct = (missing_count / len(df) * 100).round(2)

missing_summary = pd.DataFrame(
    {"missing_count": missing_count, "missing_pct": missing_pct}
).sort_values("missing_pct", ascending=False)

missing_summary[missing_summary["missing_count"] > 0]
# Out:
# Empty DataFrame
# Columns: [missing_count, missing_pct]
# Index: []

# %%
# missing by column
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent.reset_index().rename(columns={0: "missing_percent"}).sort_values(
    "missing_percent", ascending=False
)
# Out:
#                       index  missing_percent
# 0               location_id              0.0
# 1             location_name              0.0
# 2                      date              0.0
# 3                      pm10              0.0
# 4                     pm2_5              0.0
# 5           carbon_monoxide              0.0
# 6           sulphur_dioxide              0.0
# 7                     ozone              0.0
# 8          nitrogen_dioxide              0.0
# 9     aerosol_optical_depth              0.0
# 10                     dust              0.0
# 11             us_aqi_pm2_5              0.0
# 12              us_aqi_pm10              0.0
# 13  us_aqi_nitrogen_dioxide              0.0
# 14   us_aqi_carbon_monoxide              0.0
# 15             us_aqi_ozone              0.0
# 16   us_aqi_sulphur_dioxide              0.0
# 17                   us_aqi              0.0
# 18           temperature_2m              0.0
# 19     relative_humidity_2m              0.0
# 20                     rain              0.0
# 21         surface_pressure              0.0
# 22              cloud_cover              0.0
# 23           wind_speed_10m              0.0
# 24       wind_direction_10m              0.0
# 25             weather_code              0.0
# 26        sunshine_duration              0.0
# 27    boundary_layer_height              0.0
# 28             dew_point_2m              0.0
# 29                   is_day              0.0

# %%
col_to_check = "boundary_layer_height"

if df[col_to_check].isnull().sum() > 0:
    missing_by_location = df[df[col_to_check].isnull()].groupby("location_name").size()
    print(f"Missing '{col_to_check}' by location:")
    print(missing_by_location)
    print()
    missing_dates = df[df[col_to_check].isnull()]["date"]
    print(
        f"Date range of missing values: [{missing_dates.min()} -> {missing_dates.max()}]"
    )

# %% [markdown]
# ## Duplicated

# %%
full_dup = df.duplicated().sum()
key_dup = df.duplicated(subset=["location_id", "date"]).sum()

print(f"Rows with all columns duplicated        : {full_dup}")
print(f"Rows with duplicated (location_id,date) : {key_dup}")
# Out:
# Rows with all columns duplicated        : 0
# Rows with duplicated (location_id,date) : 0

# %% [markdown]
# ## Check gap, continous of hourly by location

# %%
for loc_id, loc_name in df[["location_id", "location_name"]].drop_duplicates().values:
    df_loc = df[df["location_id"] == loc_id].sort_values("date")
    expected_range = pd.date_range(
        start=df_loc["date"].min(), end=df_loc["date"].max(), freq="h"
    )
    missing_hours = expected_range.difference(df_loc["date"])
    if len(missing_hours) > 0:
        print(f"{loc_name:<20}: missing {len(missing_hours)} hour(s)")
    else:
        print(f"{loc_name:<20}: complete, no missing hours")
# Out:
# Ho Chi Minh City    : missing 9506 hour(s)
# Bien Hoa            : missing 9506 hour(s)
# Long Khánh          : missing 9504 hour(s)
# Thu Dau Mot         : missing 9506 hour(s)
# Thuận An            : missing 9506 hour(s)
# Dĩ An               : missing 9506 hour(s)
# Thanh Pho Ba Ria    : missing 9504 hour(s)
# Vũng Tàu            : missing 9504 hour(s)
# Tay Ninh            : missing 9504 hour(s)
# Dong Xoai           : missing 9504 hour(s)

# %% [markdown]
# ## Univariate

# %% [markdown]
# ## Weather

# %% [markdown]
# ### Numerical

# %%
weather_numeric_cols = [
    "temperature_2m",
    "relative_humidity_2m",
    "rain",
    "surface_pressure",
    "cloud_cover",
    "wind_speed_10m",
    "wind_direction_10m",
    "sunshine_duration",
    "boundary_layer_height",
    "dew_point_2m",
]

df[weather_numeric_cols].describe().T
# Out:
#                           count         mean          std         min  \
# temperature_2m         246640.0    27.023671     3.041614   14.900000
# relative_humidity_2m   246640.0    79.162674    15.677445   21.913445
# rain                   246640.0     0.259584     1.059911    0.000000
# surface_pressure       246640.0  1005.400402     6.149404  980.791140
# cloud_cover            246640.0    76.377088    34.232679    0.000000
# wind_speed_10m         246640.0     8.671352     5.386082    0.000000
# wind_direction_10m     246640.0   169.122636    95.833977    0.682054
# sunshine_duration      246640.0  1459.331634  1727.046876    0.000000
# boundary_layer_height  246640.0   513.038964   441.713790   10.000000
# dew_point_2m           246640.0    22.705036     2.444820    8.550000
#
#                                25%          50%          75%          max
# temperature_2m           24.800000    26.500000    29.050000    39.400000
# relative_humidity_2m     69.559284    82.706180    92.267770   100.000000
# rain                      0.000000     0.000000     0.100000    35.700000
# surface_pressure       1004.134900  1007.247560  1009.259500  1017.707640
# cloud_cover              56.000000    98.000000   100.000000   100.000000
# wind_speed_10m            4.752137     7.434676    11.384199    42.303448
# wind_direction_10m       95.710500   155.323150   243.435010   360.000000
# sunshine_duration         0.000000     0.000000  3600.000000  3600.000000
# boundary_layer_height   170.000000   390.000000   720.000000  2865.000000
# dew_point_2m             21.550000    23.550000    24.400000    27.450000

# %% [markdown]
# **Range**:
#
# - `relative_humidity_2m` must be in [0, 100]
# - `cloud_cover` must be in [0, 100]
# - `wind_direction_10m` must be in [0, 360]
# - `rain`, `sunshine_duration`, `boundary_layer_height` not negative

# %%
range_checks = {
    "relative_humidity_2m": (0, 100),
    "cloud_cover": (0, 100),
    "wind_direction_10m": (0, 360),
}

for col, (lo, hi) in range_checks.items():
    invalid = df[(df[col] < lo) | (df[col] > hi)]
    print(f"{col:<25} out of [{lo},{hi}]      : {len(invalid)} rows")

non_negative_cols = ["rain", "sunshine_duration", "boundary_layer_height"]
for col in non_negative_cols:
    invalid = df[df[col] < 0]
    print(f"{col:<25} has negative values : {len(invalid)} rows")
# Out:
# relative_humidity_2m      out of [0,100]      : 0 rows
# cloud_cover               out of [0,100]      : 0 rows
# wind_direction_10m        out of [0,360]      : 0 rows
# rain                      has negative values : 0 rows
# sunshine_duration         has negative values : 0 rows
# boundary_layer_height     has negative values : 0 rows

# %%
fig, axes = plt.subplots(
    len(weather_numeric_cols), 2, figsize=(16, 4 * len(weather_numeric_cols))
)

for i, col in enumerate(weather_numeric_cols):
    sns.histplot(df[col].dropna(), stat="density", color="orange", ax=axes[i, 0])
    sns.kdeplot(df[col].dropna(), color="red", linewidth=3, ax=axes[i, 0])
    axes[i, 0].set_title(f"Histogram: {col}")
    sns.boxplot(x=df[col], ax=axes[i, 1], color="orange")
    axes[i, 1].set_title(f"Boxplot: {col}")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical

# %%
weather_category_cols = [
    "weather_code",
    "is_day",
]

# %%
for col in weather_category_cols:
    print(f"{col} unique values: {df[col].nunique()}")
    print(df[col].unique())
    print()
# Out:
# weather_code unique values: 10
# [ 3. 51. 63. 61. 55. 53.  2.  1.  0. 65.]
#
# is_day unique values: 2
# [1. 0.]

# %%
for col in weather_category_cols:
    plt.figure(figsize=(16, 4))
    sns.countplot(x=col, data=df, palette="YlOrRd")
    plt.title(f"Countplot: {col}")
    plt.show()

# %% [markdown]
# ## Air Quality

# %%
aqi_cols = [
    "pm10",
    "pm2_5",
    "carbon_monoxide",
    "sulphur_dioxide",
    "ozone",
    "nitrogen_dioxide",
    "aerosol_optical_depth",
    "dust",
    "us_aqi_pm2_5",
    "us_aqi_pm10",
    "us_aqi_nitrogen_dioxide",
    "us_aqi_carbon_monoxide",
    "us_aqi_ozone",
    "us_aqi_sulphur_dioxide",
    "us_aqi",
]

# %%
df[aqi_cols].describe().T
# Out:
#                             count        mean         std        min  \
# pm10                     246640.0   28.665603   16.102365   0.200000
# pm2_5                    246640.0   21.558115   13.067038   0.200000
# carbon_monoxide          246640.0  394.231657  272.219296  59.000000
# sulphur_dioxide          246640.0   12.671487   12.981946   0.000000
# ozone                    246640.0   63.439479   40.837495  -1.000000
# nitrogen_dioxide         246640.0   20.276898   18.235674   0.000000
# aerosol_optical_depth    246640.0    0.320626    0.188323   0.020000
# dust                     246640.0    0.357760    1.119239   0.000000
# us_aqi_pm2_5             246640.0   73.067615   21.739894   3.171296
# us_aqi_pm10              246640.0   25.907782   11.303010   0.731061
# us_aqi_nitrogen_dioxide  246640.0    9.988984    8.996481   0.000000
# us_aqi_carbon_monoxide   246640.0    3.807425    2.357709   0.570048
# us_aqi_ozone             246640.0   32.254037   24.425789   0.000000
# us_aqi_sulphur_dioxide   246640.0    6.909182    7.078323   0.000000
# us_aqi                   246640.0   74.651572   23.485689  12.059369
#
#                                 25%         50%         75%         max
# pm10                      17.400000   24.900000   36.200000   203.00000
# pm2_5                     12.500000   18.300000   27.100000   200.70000
# carbon_monoxide          224.000000  318.000000  473.000000  5339.00000
# sulphur_dioxide            3.400000    7.800000   18.100000    96.60000
# ozone                     32.000000   58.000000   89.000000   357.00000
# nitrogen_dioxide           6.300000   14.100000   30.200000   170.35000
# aerosol_optical_depth      0.200000    0.280000    0.390000     2.63000
# dust                       0.000000    0.000000    0.000000    36.00000
# us_aqi_pm2_5              58.223270   69.135216   84.103775   177.29167
# us_aqi_pm10               17.356060   23.829548   32.928030    70.10834
# us_aqi_nitrogen_dioxide    3.102837    6.944445   14.873916    89.79533
# us_aqi_carbon_monoxide     2.259662    3.177536    4.624396    33.56522
# us_aqi_ozone              17.277367   28.119200   39.772728   249.98654
# us_aqi_sulphur_dioxide     1.853872    4.252999    9.869139    52.33779
# us_aqi                    58.577040   69.937110   85.746852   249.98654

# %%
fig, axes = plt.subplots(len(aqi_cols), 2, figsize=(16, 4 * len(aqi_cols)))

for i, col in enumerate(aqi_cols):
    sns.histplot(df[col].dropna(), stat="density", color="orange", ax=axes[i, 0])
    sns.kdeplot(df[col].dropna(), color="red", linewidth=3, ax=axes[i, 0])
    axes[i, 0].set_title(f"Histogram: {col}")
    sns.boxplot(x=df[col], ax=axes[i, 1], color="orange")
    axes[i, 1].set_title(f"Boxplot: {col}")
plt.tight_layout()
plt.show()

# %%
# Check if us_aqi is the maximum value of the 6 components
components = [
    "us_aqi_pm2_5",
    "us_aqi_pm10",
    "us_aqi_nitrogen_dioxide",
    "us_aqi_carbon_monoxide",
    "us_aqi_ozone",
    "us_aqi_sulphur_dioxide",
]
calculated_max = df[components].max(axis=1)
mismatch = (df["us_aqi"] != calculated_max).sum()
print(f"Row mismatch that don't match the maximum: {mismatch} / {len(df)}")
# Out:
# Row mismatch that don't match the maximum: 0 / 246640

# %% [markdown]
# # Label

# %%
def aqi_to_category(value):
    if value <= 50:
        return "good"
    elif value <= 100:
        return "moderate"
    elif value <= 150:
        return "unhealthy for sensitive groups"
    elif value <= 200:
        return "unhealthy"
    elif value <= 300:
        return "very unhealthful"
    else:
        return "hazardous"


df["aqi_category"] = df["us_aqi"].apply(aqi_to_category)

category_order = [
    "good",
    "moderate",
    "unhealthy for sensitive groups",
    "unhealthy",
    "very unhealthful",
    "hazardous",
]

label_dist = (
    df["aqi_category"].value_counts(normalize=True).reindex(category_order).fillna(0)
    * 100
)
print(label_dist.round(2))
# Out:
# aqi_category
# good                               7.64
# moderate                          80.20
# unhealthy for sensitive groups    10.88
# unhealthy                          1.21
# very unhealthful                   0.06
# hazardous                          0.00
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(16, 5))
sns.countplot(data=df, x="aqi_category", order=category_order, palette="YlOrRd")
plt.title("Distribution of AQI Categories")
plt.xlabel("AQI Category")
plt.ylabel("Record")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()

# %%
counts = df["aqi_category"].value_counts()
imbalance_ratio = counts.max() / counts.min()
print(f"Class largest  : {counts.idxmax()} ({counts.max():,} row)")
print(f"Class smallest : {counts.idxmin()} ({counts.min():,} row)")
print(f"Imbalance Ratio: {imbalance_ratio:.1f}")
# Out:
# Class largest  : moderate (197,817 row)
# Class smallest : very unhealthful (154 row)
# Imbalance Ratio: 1284.5

# %% [markdown]
# # Save

# %%
df.to_csv("../data/clean/data1.csv", index=False)
